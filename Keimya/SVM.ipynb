# %% [markdown]
# **SVM \(Support Vector Machine\):** supervised machine learning model that uses classification algorithm for two\-group classification problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statistics
from sklearn.linear_model import LinearRegression

# %%
filename = "./NKI_cleaned.csv"
my_data = pd.read_csv(filename)

# %%
my_data.head(10)
# Out:
#   Patient  ID  age  eventdeath   survival  timerecurrence  chemo  hormonal  \
# 0    s122  18   43           0  14.817248       14.817248      0         0
# 1    s123  19   48           0  14.261465       14.261465      0         0
# 2    s124  20   38           0   6.644764        6.644764      0         0
# 3    s125  21   50           0   7.748118        7.748118      0         1
# 4    s126  22   38           0   6.436687        6.318960      0         0
# 5    s127  23   42           0   5.037645        2.743326      1         0
# 6    s128  24   50           0   8.739220        8.739220      1         1
# 7    s129  25   43           0   7.567420        7.567420      1         0
# 8    s130  26   47           0   7.296372        7.296372      1         0
# 9    s131  27   39           1   4.662560        1.114305      0         0
#
#    amputation  histtype  ...  Contig36312_RC  Contig38980_RC  NM_000853  \
# ...

# %%
my_data.dropna(inplace = True)
my_data.drop_duplicates(inplace = True)
my_data = my_data.reset_index(drop=True)

length = len(my_data.index)

# %% [markdown]
# <u>**Time Recurrence**</u>

# %%
my_data["timerecurrence"].min()
# Out:
# 0.271047

# %%
my_data["timerecurrence"].max()
# Out:
# 18.340862

# %% [markdown]
# <u>**Survival**</u>

# %%
my_data["survival"].min()
# Out:
# 0.711841

# %%
my_data["survival"].max()
# Out:
# 18.340862

# %%
my_data["survival"].mean()
# Out:
# 8.080608937500001

# %%
plt.hist(my_data["survival"])
# Out:
# (array([18., 23., 47., 56., 37., 38., 21., 11., 11., 10.]),
#  array([ 0.711841 ,  2.4747431,  4.2376452,  6.0005473,  7.7634494,
#          9.5263515, 11.2892536, 13.0521557, 14.8150578, 16.5779599,
#         18.340862 ]),
#  <a list of 10 Patch objects>)

# %%
#for survival < 10,= low
#for survival > 10 = high

# %%
def divide_survival(x):
    if x <= 10:
        return "low"
    else:
        return "high"

# %%
my_data["survival"].apply(divide_survival)
# Out:
# 0      high
# 1      high
# 2       low
# 3       low
# 4       low
#        ...
# 267     low
# 268     low
# 269     low
# 270     low
# 271     low
# Name: survival, Length: 272, dtype: object

# %%
my_data["survival_type"] = my_data ["survival"].apply(divide_survival)

# %%
my_data
# Out:
#     Patient   ID  age  eventdeath   survival  timerecurrence  chemo  hormonal  \
# 0      s122   18   43           0  14.817248       14.817248      0         0
# 1      s123   19   48           0  14.261465       14.261465      0         0
# 2      s124   20   38           0   6.644764        6.644764      0         0
# 3      s125   21   50           0   7.748118        7.748118      0         1
# 4      s126   22   38           0   6.436687        6.318960      0         0
# ..      ...  ...  ...         ...        ...             ...    ...       ...
# 267     s71  308   48           1   2.608300        1.982204      1         0
# 268     s72  309   39           1   5.504100        3.028063      0         0
# 269     s73  310   50           1   2.619200        2.149213      0         0
# 270     s75  311   52           1   2.290500        2.209446      0         1
# 271     s76  312   52           1   3.737000        2.127310      0         0
#
# ...

# %%
from sklearn import svm

# %%
x= my_data [["chemo", "hormonal"]].to_numpy()
y= my_data ["survival_type"]

# %%
idx = np.arange (len(x))
np.random.shuffle(idx)

split_threshold = int(len(x)* 0.8)

# %%
x_train = x[:split_threshold]
x_test = x[split_threshold:]

y_train = y[:split_threshold]
y_test = y[split_threshold:]

# %%
clf = svm.SVC()

# %%
clf.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_hat = clf.predict (x_test)
y_hat
# Out:
# array(['low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low'], dtype=object)

# %%
y_test
# Out:
# 217     low
# 218    high
# 219    high
# 220    high
# 221    high
# 222    high
# 223     low
# 224     low
# 225     low
# 226     low
# 227     low
# 228     low
# 229     low
# 230     low
# 231     low
# 232    high
# 233    high
# 234     low
# 235     low
# 236    high
# 237     low
# 238     low
# 239     low
# 240     low
# 241     low
# 242     low
# 243     low
# 244     low
# 245     low
# 246    high
# 247    high
# 248    high
# 249     low
# 250    high
# 251     low
# 252     low
# 253     low
# 254     low
# 255     low
# 256     low
# 257     low
# 258    high
# 259    high
# 260    high
# 261     low
# 262     low
# 263     low
# 264     low
# 265     low
# 266     low
# 267     low
# 268     low
# 269     low
# 270     low
# 271     low
# Name: survival_type, dtype: object

# %%
import plotly.express as px

# %%
fig = px.bar(my_data, x = 'age', y = 'survival')
fig.update_traces(marker_color ='red')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Random Forest:** a machine learning technique that’s used to solve regression and classification problems. It utilizes ensemble learning, which is a technique that combines many classifiers to provide solutions to complex problems.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn import svm

# %%
x= my_data [["chemo", "hormonal"]].to_numpy()

# %%
y= my_data ["survival_type"]

# %%
idx= np.arange(len(x))
np.random.shuffle(idx)

split_threshold = int(len(x)* 0.8)

# %%
x_train= x[:split_threshold]
x_test= x[split_threshold:]

y_train= x[:split_threshold]
y_test= x[split_threshold:]

# %%
clf = RandomForestClassifier(max_depth= 3, random_state = 0, n_estimators = 20  )

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=20, random_state=0)

# %%
y_hat = clf.predict(x_test)

# %%
from sklearn.tree import export_graphviz
estimator = clf.estimators_[15]

# %%
export_graphviz(estimator, out_file= 'tree.dot',
                rounded = True, proportion = False,
                precision =2, filled =True)

# %%
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])

from IPython.display import Image
Image(filename = 'tree.png')
